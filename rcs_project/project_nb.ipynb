# %%
from PIL import Image
import rcs_fun as fun

# %%
img = Image.open('../data/wallpaper.jpg')
img2 = Image.open('../data/bridge.png')

print("The wallpaper of size", img.size,"to reproduce:\n")
img
# Out:
# The wallpaper of size (900, 506) to reproduce:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x506>

# %%
# We have created two functions to reproduce the wallpaper (or any image) with hexagons
# the first compute the color of each hexagon by taking the color of the center of the hexagon,
# the second compute the color of each hexagon by taking the average of the colors of the pixels in the hexagon.

fun.hexagonal_grid_svg1(img, 10)

# %%
fun.hexagonal_grid_svg2(img, 10)

# The second function is more precise, the colors are more accurate.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# c:\Users\oanou\OneDrive - Centrale Lille\M1\RCS\RCS_project\rcs_project\project_nb.ipynb Cell 4 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/oanou/OneDrive%20-%20Centrale%20Lille/M1/RCS/RCS_project/rcs_project/project_nb.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> fun.hexagonal_grid_svg2(img, 10)
#       <a href='vscode-notebook-cell:/c%3A/Users/oanou/OneDrive%20-%20Centrale%20Lille/M1/RCS/RCS_project/rcs_project/project_nb.ipynb#W3sZmlsZQ%3D%3D?line=2'>3</a> # The second function is more precise, the colors are more accurate.
#
# File c:\Users\oanou\OneDrive - Centrale Lille\M1\RCS\RCS_project\rcs_project\rcs_fun.py:248, in hexagonal_grid_svg2(img, hex_size)
#     246 for j in range(hex_y):
#     247     if (i+j)%2 == 0:
# --> 248         color = get_color2(x + hex_size/2, y + hex_size*np.sqrt(3)/2, img)
#     249         dwg.add(dwg.polygon(points=hexagon(x, y, hex_size), fill=svg.rgb(color[0], color[1], color[2])))
#     250     y += hex_size*np.sqrt(3)/2
#
# File c:\Users\oanou\OneDrive - Centrale Lille\M1\RCS\RCS_project\rcs_project\rcs_fun.py:51, in get_color2(img, center, hex_size)
#      39 def get_color2(img, center, hex_size):
#      40     """Returns the average color of the hexagon whose center is center and size is hex_size
#      41
#      42     Args:
#    (...)
#      48         pixel (tuple): Tuple of the RGB values of the average color of the hexagon
#      49     """
# ---> 51     x=center[0]
#      52     y=center[1]
#      53     min_x = max(int(np.floor(x - hex_size)), 0)
#
# IndexError: invalid index to scalar variable.

# %%
# We try to compute the function with a bigger and more detailed image

fun.hexagonal_grid_png2(img2, 20)
# Out:
# <PIL.Image.Image image mode=RGB size=3000x1500>
