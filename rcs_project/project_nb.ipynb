# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import rcs_fun as fun

# %%
img = Image.open('../data/wallpaper.jpg')

print("The wallpaper to reproduce:\n")
img
# Out:
# The wallpaper to reproduce:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=900x506>

# %%
# We first use the function `hexagon` to create the hexagonal grid.
